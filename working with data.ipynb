# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns
pd.set_option("display.max_column", None)

# %% [markdown]
# ### Task 1

# %%
df = pd.read_csv("./movie_metadata.csv")

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# ### 1.2. The duration column contains data on the film length. How many missing values are there in this column?

# %%
duration_missing_values = df["duration"].isna().sum()
duration_missing_values
# Out:
# 15

# %% [markdown]
# ### 1.3.

# %%
df["duration"].median()
# Out:
# 103.0

# %%
df['duration'].fillna(df["duration"].median(), inplace=True)

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN     103.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %% [markdown]
# ### 1.4.

# %%
avg_film_length = df.duration.mean()
avg_film_length
# Out:
# 107.18857822724569

# %%
df[df["title_year"] >= 2000].describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             3559.000000  3597.000000              3597.000000
# mean               164.099747   106.326105               560.721435
# std                131.142289    20.084571              2528.497778
# min                  1.000000     7.000000                 0.000000
# 25%                 65.000000    93.000000                 7.000000
# 50%                138.000000   103.000000                46.000000
# 75%                230.000000   116.000000               180.000000
# max                813.000000   300.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             3581.000000             3590.000000  3.070000e+03
# mean               724.050824             7201.938440  4.884831e+07
# std               1890.474136            16923.476267  7.088449e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
# df["movie_duration_category"] = df["duration"]

# %%
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN     103.0
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# ### 1.5.

# %%
conditions = [
   ( df['duration'] <90), (df['duration'] >=90) & (df['duration'] <=120), (df['duration'] >120)
]

values = [
    "category1", "category2", "category3"
]
value = [
    "<90", "90-120", ">120"
]

# %%
# df['movie_duration_category'].loc[df['duration'] < 90, 'duration'] = "category1"
# # df.loc[(df["movie_duration_category"] >89) & (df["movie_duration_category"] < 201), 'movie_duration_category'] = "category2"

# %%
# df['movie_duration_category'] = np.where((df['movie_duration_category'] < 90,'category1',df['movie_duration_category']),(((df['movie_duration_category']>=90)&(df['movie_duration_category'])<=120),'category2', df['movie_duration_category']),(df['movie_duration_category']>120,'category3',df['movie_duration_category']))

# %%
# df.loc[df['movie_duration_category'] <90, 'movie_duration_category'] = "category1"

# %%
# df[df['movie_duration_category'] > 90 & df['movie_duration_category'] < 201]

# %%
# df.movie_duration_category.mask((df['duration']>89) & (df['duration'] < 120),'category2', inplace=True)

# %%
# df.movie_duration_category.mask(df['duration']<90, 'category1', inplace=True)

# %%
df['duration_category'] = np.select(conditions, values)

# %% [markdown]
# ### 1.6.

# %%
df[['color', 'director_name', 'num_critic_for_reviews', 'duration','duration_category',
       'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
       'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
       'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
       'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
       'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
       'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
       'imdb_score', 'aspect_ratio', 'movie_facebook_likes',
       ]].head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN     103.0
#
#   duration_category  director_facebook_likes  actor_3_facebook_likes  \
# 0         category3                      0.0                   855.0
# 1         category3                    563.0                  1000.0
# 2         category3                      0.0                   161.0
# 3         category3                  22000.0                 23000.0
# 4         category2                    131.0                     NaN
#
#        actor_2_name  actor_1_facebook_likes        gross  \
# 0  Joel David Moore                  1000.0  760505847.0
# 1     Orlando Bloom                 40000.0  309404152.0
# ...

# %%
duration = df[['duration_category','duration']].groupby('duration_category').count()
duration
# Out:
#                    duration
# duration_category
# category1               792
# category2              3184
# category3              1067

# %%
df['duration_group'] = np.select(conditions, value)
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN     103.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
df_2000 =df[df['title_year'] >=2000]
new_df = df_2000[['title_year','duration_group']]
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3597 entries, 0 to 5042
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title_year      3597 non-null   float64
#  1   duration_group  3597 non-null   object
# dtypes: float64(1), object(1)
# memory usage: 84.3+ KB

# %%
# new_df['title_year'] = new_df['title_year'].astype(float).astype(str)

# %% [markdown]
# ### 1.7.

# %%
df_2008 = new_df[new_df['title_year'] ==2008]
df_2008
# Out:
#       title_year duration_group
# 12        2008.0         90-120
# 16        2008.0           >120
# 54        2008.0           >120
# 58        2008.0         90-120
# 66        2008.0           >120
# ...          ...            ...
# 4888      2008.0         90-120
# 4904      2008.0            <90
# 4909      2008.0            <90
# 4913      2008.0            <90
# 4917      2008.0            <90
#
# [225 rows x 2 columns]

# %%
df_2008[df_2008['duration_group'] == '90-120'].count()
# Out:
# title_year        160
# duration_group    160
# dtype: int64

# %%
df.count().max()
# Out:
# 5043

# %%
df["plot_keywords"].isna().sum()
# Out:
# 153

# %% [markdown]
# ### 1.8.

# %%
clean_df = df[~df["plot_keywords"].isna()]
clean_dfc = clean_df.copy()

# %%
ld_group = ['love','death']
lgroup = ['love']
dgroup = ['death']
condition =[
    clean_dfc['plot_keywords'].str.contains('|'.join(ld_group)), clean_dfc['plot_keywords'].str.contains('|'.join(lgroup)), clean_dfc['plot_keywords'].str.contains('|'.join(dgroup))
]
value = [
    'love_and_death','love', 'death'
]

# %% [markdown]
# ### 1.9. ,1.10.

# %%
# newer_dfc=clean_dfc['movie_plot_category'] = np.select(condition, value,"")

# %%
#clean_df.loc[clean_df["plot_keywords"].str.contains('|'.join(ld_group)), 'movie_plot_category'] = "love_and_death"

# %%
# mask1 = clean_dfc['plot_keywords'].str.contains('love') & clean_dfc['plot_keywords'].str.contains('death')
# mask = clean_dfc['plot_keywords'].str.contains('love')
# mask1 = clean_dfc['plot_keywords'].str.contains('death')
# clean_dfc.loc[mask, 'movie_plot_category'] = 'love'
# clean_dfc.loc[mask1, 'movie_plot_category'] = 'love_and_death'
# clean_dfc.head()

# %%
split = pd.Series('|'.join(clean_dfc['plot_keywords']).split())
split_again = []
for x in split:
    if 'love' and 'death' in x:
        split_again.append('love_and_death')
    elif 'love' in x:
        split_again.append('love')
    elif 'death' in x:
        split_again.append('death')

split_again = pd.DataFrame(split_again)
split_again
clean_dfc['movie_plot_category'] = split_again
clean_dfc['movie_plot_category'].fillna('other', inplace=True)

# %%
round(clean_dfc[['movie_plot_category', 'imdb_score']].groupby(['movie_plot_category']).mean().sort_values('imdb_score', ascending=False).reset_index(),2)
# Out:
#   movie_plot_category  imdb_score
# 0                love        6.71
# 1      love_and_death        6.62
# 2               other        6.43

# %% [markdown]
# ### 1.11.

# %%
df['budget'] = [x.strip('$') for x in df['budget']]
df['budget'] = df['budget'].astype(float)

# %%
df['budget'] = df.budget.astype(int)

# %%
df.budget.dtype
# Out:
# dtype('int32')

# %%
mid_budget = df.budget.median()

# %%
mid_budget
# Out:
# 15000000.0

# %%
df['title_year'].dtype
# Out:
# dtype('float64')

# %%
df['title_year'] = pd.to_datetime(df['title_year'])
df.title_year.dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ## Task 2

# %% [markdown]
# ### Question 1

# %%
df_event = pd.read_csv("./event_data.csv")
df_event.head()
# Out:
#   user_id           event_date    event_type  purchase_amount
# 0  c40e6a  2019-07-29 00:02:15  registration              NaN
# 1  a2b682  2019-07-29 00:04:46  registration              NaN
# 2  9ac888  2019-07-29 00:13:22  registration              NaN
# 3  93ff22  2019-07-29 00:16:47  registration              NaN
# 4  65ef85  2019-07-29 00:19:23  registration              NaN

# %%
df_event
# Out:
#       user_id           event_date    event_type  purchase_amount
# 0      c40e6a  2019-07-29 00:02:15  registration              NaN
# 1      a2b682  2019-07-29 00:04:46  registration              NaN
# 2      9ac888  2019-07-29 00:13:22  registration              NaN
# 3      93ff22  2019-07-29 00:16:47  registration              NaN
# 4      65ef85  2019-07-29 00:19:23  registration              NaN
# ...       ...                  ...           ...              ...
# 79737  930c23  2019-09-01 23:57:41  simple_event              NaN
# 79738  a84999  2019-09-01 23:57:50  simple_event              NaN
# 79739  175e4d  2019-09-01 23:59:40  simple_event              NaN
# 79740  1c2210  2019-09-01 23:59:51  simple_event              NaN
# 79741  d799dc  2019-09-01 23:59:54  simple_event              NaN
#
# [79742 rows x 4 columns]

# %%
df_event.event_date.dtype
# Out:
# dtype('O')

# %%
# removing the time for the datetime
date = pd.to_datetime(df_event['event_date'], infer_datetime_format=True).dt.date

# %%
df_event['event_date'] = pd.to_datetime(date, infer_datetime_format=True)
df_event['event_date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_event.head()
# Out:
#   user_id event_date    event_type  purchase_amount
# 0  c40e6a 2019-07-29  registration              NaN
# 1  a2b682 2019-07-29  registration              NaN
# 2  9ac888 2019-07-29  registration              NaN
# 3  93ff22 2019-07-29  registration              NaN
# 4  65ef85 2019-07-29  registration              NaN

# %% [markdown]
# ### Question 2

# %%
conditionx = [
   (df_event['event_date'] >= '2019-07-29') & (df_event['event_date'] <= '2019-08-04'), 
    (df_event['event_date'] >= '2019-08-05') & (df_event['event_date'] <= '2019-08-11'),
    (df_event['event_date'] >= '2019-08-12') & (df_event['event_date'] <= '2019-08-18'),
    (df_event['event_date'] >= '2019-08-19') & (df_event['event_date'] <= '2019-08-25'),
    (df_event['event_date'] >= '2019-08-26') & (df_event['event_date'] <= '2019-09-01'),
]

valuex = [
    "ID 31", "ID 32", "ID 33","ID 34","ID 35"
]

# %%
df_event['cohort'] = np.select(conditionx, valuex,"")

# %%
df_event.head()
# Out:
#   user_id event_date    event_type  purchase_amount cohort
# 0  c40e6a 2019-07-29  registration              NaN  ID 31
# 1  a2b682 2019-07-29  registration              NaN  ID 31
# 2  9ac888 2019-07-29  registration              NaN  ID 31
# 3  93ff22 2019-07-29  registration              NaN  ID 31
# 4  65ef85 2019-07-29  registration              NaN  ID 31

# %% [markdown]
# ### Question 3

# %%
user_id = df_event[['cohort','user_id']].groupby('cohort').count().reset_index()
user_id[user_id['cohort'] == 'ID 33']
# Out:
#   cohort  user_id
# 2  ID 33    18144

# %% [markdown]
# ## Task 3

# %% [markdown]
# ##### A DataFrame has rows and columns, much like a table. A Series is each column. A series is comparable to a single table column.
#
# ##### Imagine a DataFrame as a cookie sheet that contains a variety of cookies (Series), each with a distinct flavor (data type).
#
#
# ##### Like a single cookie with just one flavor (or data type), a series is a subset of a larger set (DataFrame).
#
# ##### Duration: 2 minutes.

# %% [markdown]
# ## Task 4

# %%
# Mean and Variance of X
mean_x = 0.5
var_x = 2

# Mean and Variance of Y
mean_y = 7
var_y = 3.5

# Covariance between X and Y
cov_xy = -0.8

# Variance of Z
var_z = (2**2) * var_x + (3**2) * var_y - 2 * 2 * 3 * cov_xy

print("The variance of Z is: ", var_z)
# Out:
# The variance of Z is:  49.1

# %% [markdown]
# ## Task 5

# %%
# Number of objects in test sample
n = 500

# Number of objects with prediction higher than expected
n_high = 400

# Number of objects with prediction lower than expected
n_low = n - n_high

# Difference in prediction for objects with prediction higher than expected
diff_high = 0.5

# Difference in prediction for objects with prediction lower than expected
diff_low = 0.7

# Omer's MSE
mse_omer = (n_high * diff_high**2 + n_low * diff_low**2) / n

# Limor's MSE
# Calculating the constant value that Limor uses to change all the answers
constant = (n_high * diff_high - n_low * diff_low) / n
# Limor's MSE is 0 as she found the smallest error
mse_limor = (n_high * (diff_high - constant)**2 + n_low * (diff_low - constant)**2) / n

print("Omer's MSE: ", mse_omer)
print("Limor's MSE: ", mse_limor)
# Out:
# Omer's MSE:  0.298
# Limor's MSE:  0.08479999999999999
